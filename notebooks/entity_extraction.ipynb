# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from chonkie import SDPMChunker
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from pyprojroot import here
import re
with open(here() / "data" / "curve-sim.md", "r+") as f:
    text = f.read()


# Remove all <!-- image --> from the text
text = re.sub(r"<!-- image -->", "", text)
# Remove all `\n`*3 or more from the text
text = re.sub(r"\n{3,}", "\n\n", text)

# %%
# Hyper-personalized knowledge graph construction.
import llamabot as lmb

sysprompt = lmb.system("""
my background training is in the following areas:

- machine learning
- biological engineering
- biochemistry

This paper was given to me by my client for review.
It pertains to their work doing chemical modelling.

Help me understand the paper
by first extracting entities from the paper.
Return the results in a structured format.
""")

# %%
from poorman_graphrag.entities import Entity, Entities
import llamabot as lmb

entity_extractor = lmb.StructuredBot(
    system_prompt=sysprompt,
    model_name="gemini/gemini-2.0-flash-exp",
    pydantic_model=Entities,
    # stream_target="none",
)

# %%
# entities_full_text = entity_extractor(text)

# %%
chunker = SDPMChunker(min_sentences=10, threshold=0.4)
chunks = chunker(text)
len(chunks)
# Out:
# 26

# %%
# Just a test
entity_extractor(chunks[0].text)
# Out:
# {
#   "entities": [
#     {
#       "description": "First author of the paper",
#       "entity_type": "author",
#       "name": "Paul Faya",
#       "quote": "Paul Faya a"
#     },
#     {
#       "description": "Second author of the paper",
#       "entity_type": "author",
#       "name": "Adam P. Rauk",
#       "quote": "Adam P. Rauk a"
#     },
#     {
#       "description": "Third author of the paper",
#       "entity_type": "author",
#       "name": "Kristi L. Griffiths",
#       "quote": "Kristi L. Griffiths a"
#     },
#     {
#       "description": "Fourth author of the paper",
#       "entity_type": "author",
#       "name": "Bhavin Parekh",
#       "quote": "Bhavin Parekh b"
#     },
#     {
#       "description": "Institution of the first three authors",
#       "entity_type": "institution",
#       "name": "Eli Lilly and Company",
#       "quote": "Statistics -Discovery/Development, Eli Lilly and Company, Indianapolis, Indiana, USA"
#     },
#      {
#       "description": "Institution of the fourth author",
#       "entity_type": "institution",
#       "name": "Eli Lilly and Company",
#       "quote": "Bioproduct R&D -Bioassay, Eli Lilly and Company"
#     },
#     {
#       "description": "General topic of the paper",
#       "entity_type": "paper",
#       "name": "parallelism testing in bioassay",
#       "quote": "A curve similarity approach to parallelism testing in bioassay"
#     },
#     {
#       "description": "A measure of biological activity",
#       "entity_type": "metric",
#       "name": "potency",
#       "quote": "Potency determination via bioassay is a relative measure"
#     },
#     {
#       "description": "A type of biological assay",
#       "entity_type": "algorithm",
#       "name": "bioassay",
#       "quote": "Potency determination via bioassay is a relative measure"
#     },
#      {
#       "description": "A standard used for comparison in bioassays",
#       "entity_type": "drug",
#       "name": "reference standard",
#       "quote": "reference standard and a sample material"
#     },
#     {
#       "description": "A material being tested in a bioassay",
#       "entity_type": "drug",
#       "name": "sample material",
#       "quote": "reference standard and a sample material"
#     },
#     {
#       "description": "A type of statistical test",
#       "entity_type": "statistical_test",
#       "name": "difference test",
#       "quote": "Typical approaches for assessing parallelism include difference ( p -value)"
#     },
#     {
#       "description": "A type of statistical test",
#       "entity_type": "statistical_test",
#       "name": "equivalence test",
#       "quote": "Typical approaches for assessing parallelism include difference ( p -value) and equivalence tests."
#     },
#     {
#       "description": "A type of curve",
#       "entity_type": "model",
#       "name": "dose-response curve",
#       "quote": "direct evaluation of the similarity of the dose -response curves."
#     },
#     {
#       "description": "A method for testing parallelism",
#       "entity_type": "algorithm",
#       "name": "curve similarity approach",
#       "quote": "We propose a simple curve similarity approach that tests the hypothesis that the sample material is a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "A statistical approach",
#        "entity_type": "algorithm",
#       "name": "frequentist approach",
#       "quote": "Both a frequentist and a Bayesian approach to the test are provided."
#     },
#     {
#       "description": "A statistical approach",
#       "entity_type": "algorithm",
#       "name": "Bayesian approach",
#       "quote": "Both a frequentist and a Bayesian approach to the test are provided."
#     },
#     {
#       "description": "A type of study",
#       "entity_type": "algorithm",
#       "name": "simulation study",
#       "quote": "We show through a simulation study that the curve similarity approach overcomes the drawbacks of the traditional methods"
#     },
#     {
#       "description": "A property of dose-response curves",
#       "entity_type": "metric",
#       "name": "parallelism",
#       "quote": "effective at detecting parallelism and non-parallelism for bioassays."
#     },
#     {
#       "description": "A keyword related to the paper",
#       "entity_type": "metric",
#       "name": "equivalence",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A keyword related to the paper",
#        "entity_type": "metric",
#       "name": "pharmaceutical",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A keyword related to the paper",
#       "entity_type": "model",
#       "name": "4PL",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A measure of drug concentration",
#       "entity_type": "metric",
#       "name": "EC50",
#       "quote": "the ratio of EC50 values can be used as a measure of the relative potency."
#     },
#      {
#       "description": "A property of dose-response curves",
#       "entity_type": "hypothesis",
#       "name": "parallel relationship",
#       "quote": "this means that the two functions (curves) should exhibit a parallel relationship."
#     }
#   ]
# }
# Entities(entities=[Entity(entity_type='author', name='Paul Faya', description='First author of the paper', quote='Paul Faya a'), Entity(entity_type='author', name='Adam P. Rauk', description='Second author of the paper', quote='Adam P. Rauk a'), Entity(entity_type='author', name='Kristi L. Griffiths', description='Third author of the paper', quote='Kristi L. Griffiths a'), Entity(entity_type='author', name='Bhavin Parekh', description='Fourth author of the paper', quote='Bhavin Parekh b'), Entity(entity_type='institution', name='Eli Lilly and Company', description='Institution of the first three authors', quote='Statistics -Discovery/Development, Eli Lilly and Company, Indianapolis, Indiana, USA'), Entity(entity_type='institution', name='Eli Lilly and Company', description='Institution of the fourth author', quote='Bioproduct R&D -Bioassay, Eli Lilly and Company'), Entity(entity_type='paper', name='parallelism testing in bioassay', description='General topic of the paper', quote='A curve similarity approach to parallelism testing in bioassay'), Entity(entity_type='metric', name='potency', description='A measure of biological activity', quote='Potency determination via bioassay is a relative measure'), Entity(entity_type='algorithm', name='bioassay', description='A type of biological assay', quote='Potency determination via bioassay is a relative measure'), Entity(entity_type='drug', name='reference standard', description='A standard used for comparison in bioassays', quote='reference standard and a sample material'), Entity(entity_type='drug', name='sample material', description='A material being tested in a bioassay', quote='reference standard and a sample material'), Entity(entity_type='statistical_test', name='difference test', description='A type of statistical test', quote='Typical approaches for assessing parallelism include difference ( p -value)'), Entity(entity_type='statistical_test', name='equivalence test', description='A type of statistical test', quote='Typical approaches for assessing parallelism include difference ( p -value) and equivalence tests.'), Entity(entity_type='model', name='dose-response curve', description='A type of curve', quote='direct evaluation of the similarity of the dose -response curves.'), Entity(entity_type='algorithm', name='curve similarity approach', description='A method for testing parallelism', quote='We propose a simple curve similarity approach that tests the hypothesis that the sample material is a dilution or concentration of the reference standard.'), Entity(entity_type='algorithm', name='frequentist approach', description='A statistical approach', quote='Both a frequentist and a Bayesian approach to the test are provided.'), Entity(entity_type='algorithm', name='Bayesian approach', description='A statistical approach', quote='Both a frequentist and a Bayesian approach to the test are provided.'), Entity(entity_type='algorithm', name='simulation study', description='A type of study', quote='We show through a simulation study that the curve similarity approach overcomes the drawbacks of the traditional methods'), Entity(entity_type='metric', name='parallelism', description='A property of dose-response curves', quote='effective at detecting parallelism and non-parallelism for bioassays.'), Entity(entity_type='metric', name='equivalence', description='A keyword related to the paper', quote='Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL'), Entity(entity_type='metric', name='pharmaceutical', description='A keyword related to the paper', quote='Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL'), Entity(entity_type='model', name='4PL', description='A keyword related to the paper', quote='Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL'), Entity(entity_type='metric', name='EC50', description='A measure of drug concentration', quote='the ratio of EC50 values can be used as a measure of the relative p ...

# %%
from tqdm.auto import tqdm

entities_from_chunks = []
for chunk in tqdm(chunks, total=len(chunks)):
    entities = entity_extractor(chunk.text)
    entities_from_chunks.append(entities)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# {
#   "entities": [
#     {
#       "description": "First author of the paper",
#       "entity_type": "author",
#       "name": "Paul Faya",
#       "quote": "Paul Faya a"
#     },
#     {
#       "description": "Second author of the paper",
#       "entity_type": "author",
#       "name": "Adam P. Rauk",
#       "quote": "Adam P. Rauk a"
#     },
#     {
#       "description": "Third author of the paper",
#       "entity_type": "author",
#       "name": "Kristi L. Griffiths",
#       "quote": "Kristi L. Griffiths a"
#     },
#     {
#       "description": "Fourth author of the paper",
#       "entity_type": "author",
#       "name": "Bhavin Parekh",
#       "quote": "Bhavin Parekh b"
#     },
#     {
#       "description": "Institution of the first three authors",
#       "entity_type": "institution",
#       "name": "Eli Lilly and Company",
#       "quote": "Statistics -Discovery/Development, Eli Lilly and Company, Indianapolis, Indiana, USA"
#     },
#      {
#       "description": "Institution of the fourth author",
#       "entity_type": "institution",
#       "name": "Eli Lilly and Company",
#       "quote": "Bioproduct R&D -Bioassay, Eli Lilly and Company"
#     },
#     {
#       "description": "General topic of the paper",
#       "entity_type": "paper",
#       "name": "parallelism testing in bioassay",
#       "quote": "A curve similarity approach to parallelism testing in bioassay"
#     },
#     {
#       "description": "A measure of biological activity",
#       "entity_type": "metric",
#       "name": "potency",
#       "quote": "Potency determination via bioassay is a relative measure"
#     },
#     {
#       "description": "A type of biological assay",
#       "entity_type": "algorithm",
#       "name": "bioassay",
#       "quote": "Potency determination via bioassay is a relative measure"
#     },
#      {
#       "description": "A standard used for comparison in bioassays",
#       "entity_type": "drug",
#       "name": "reference standard",
#       "quote": "reference standard and a sample material"
#     },
#     {
#       "description": "A material being tested in a bioassay",
#       "entity_type": "drug",
#       "name": "sample material",
#       "quote": "reference standard and a sample material"
#     },
#     {
#       "description": "A type of statistical test",
#       "entity_type": "statistical_test",
#       "name": "difference test",
#       "quote": "Typical approaches for assessing parallelism include difference ( p -value)"
#     },
#     {
#       "description": "A type of statistical test",
#       "entity_type": "statistical_test",
#       "name": "equivalence test",
#       "quote": "Typical approaches for assessing parallelism include difference ( p -value) and equivalence tests."
#     },
#     {
#       "description": "A type of curve",
#       "entity_type": "model",
#       "name": "dose-response curve",
#       "quote": "direct evaluation of the similarity of the dose -response curves."
#     },
#     {
#       "description": "A method for testing parallelism",
#       "entity_type": "algorithm",
#       "name": "curve similarity approach",
#       "quote": "We propose a simple curve similarity approach that tests the hypothesis that the sample material is a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "A statistical approach",
#        "entity_type": "algorithm",
#       "name": "frequentist approach",
#       "quote": "Both a frequentist and a Bayesian approach to the test are provided."
#     },
#     {
#       "description": "A statistical approach",
#       "entity_type": "algorithm",
#       "name": "Bayesian approach",
#       "quote": "Both a frequentist and a Bayesian approach to the test are provided."
#     },
#     {
#       "description": "A type of study",
#       "entity_type": "algorithm",
#       "name": "simulation study",
#       "quote": "We show through a simulation study that the curve similarity approach overcomes the drawbacks of the traditional methods"
#     },
#     {
#       "description": "A property of dose-response curves",
#       "entity_type": "metric",
#       "name": "parallelism",
#       "quote": "effective at detecting parallelism and non-parallelism for bioassays."
#     },
#     {
#       "description": "A keyword related to the paper",
#       "entity_type": "metric",
#       "name": "equivalence",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A keyword related to the paper",
#        "entity_type": "metric",
#       "name": "pharmaceutical",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A keyword related to the paper",
#       "entity_type": "model",
#       "name": "4PL",
#       "quote": "Equivalence; potency; pharmaceutical; reference standard; dose-response; 4PL"
#     },
#     {
#       "description": "A measure of drug concentration",
#       "entity_type": "metric",
#       "name": "EC50",
#       "quote": "the ratio of EC50 values can be used as a measure of the relative potency."
#     },
#      {
#       "description": "A property of dose-response curves",
#       "entity_type": "hypothesis",
#       "name": "parallel relationship",
#       "quote": "this means that the two functions (curves) should exhibit a parallel relationship."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A statistical test used to assess the similarity of two curves.",
#       "entity_type": "statistical_test",
#       "name": "parallelism testing",
#       "quote": "Therefore, as a prerequisite to calculating and reporting a relative potency result via bioassay, it is necessary to assess the parallelism of the test sample and reference standard curves."
#     },
#     {
#       "description": "A chapter in the U.S. Pharmacopeia that provides recommendations for methods to test for parallelism.",
#       "entity_type": "paper",
#       "name": "Chapter <1032> of the U.S. Pharmacopeia (USP)",
#       "quote": "Chapter <1032> of the U.S. Pharmacopeia (USP) (2019) and chapter 5.3 of the European Pharmacopoeia (2019) both provide recommendations for methods to test for parallelism."
#     },
#     {
#       "description": "A chapter in the European Pharmacopoeia that provides recommendations for methods to test for parallelism.",
#       "entity_type": "paper",
#       "name": "chapter 5.3 of the European Pharmacopoeia",
#       "quote": "Chapter <1032> of the U.S. Pharmacopeia (USP) (2019) and chapter 5.3 of the European Pharmacopoeia (2019) both provide recommendations for methods to test for parallelism."
#     },
#      {
#       "description": "A statistical approach to test for parallelism.",
#       "entity_type": "statistical_test",
#       "name": "p-value approach",
#       "quote": "Traditionally, the test for parallelism has been performed using statistical significance ( p -value approach) or ' difference testing ' ."
#     },
#     {
#       "description": "A statistical approach to test for parallelism.",
#       "entity_type": "statistical_test",
#       "name": "difference testing",
#       "quote": "Traditionally, the test for parallelism has been performed using statistical significance ( p -value approach) or ' difference testing ' ."
#     },
#     {
#       "description": "A mathematical model used to model dose-response data.",
#       "entity_type": "model",
#       "name": "four-parameter nonlinear logistic curve (4PL)",
#       "quote": "Thefour-parameternonlinearlogisticcurve(4PL)isperhapsmostcommonlyused to model the dose -response data."
#     },
#     {
#       "description": "A statistical test used to compare the parameters of the 4PL model.",
#       "entity_type": "statistical_test",
#       "name": "F or χ 2 statistics",
#       "quote": "As such, difference tests for parallelism typically involve testing the hypothesis of equal slopes and asymptotes via F or χ 2 statistics (Gottschalk and Dunn 2005,Yangetal. 2012)."
#     },
#     {
#       "description": "A statistical approach to test for parallelism.",
#        "entity_type": "hypothesis",
#       "name": "hypothesis of equivalence",
#       "quote": "More recently, a hypothesis of equivalence has been proposed to overcome some of the fundamental flaws of the difference approach (see Jonkman and Sidik 2009;SidikandJonkman2016)."
#     },
#     {
#       "description": "A statistical test used to assess parallelism.",
#       "entity_type": "statistical_test",
#       "name": "F-test",
#       "quote": "Both the traditional F -test and the equivalence approach aim at assessing parallelism by considering statistical differences between corresponding parameters of the 4PL model."
#     },
#      {
#       "description": "A statistical approach to test for parallelism.",
#       "entity_type": "hypothesis",
#       "name": "Bayesian approach",
#       "quote": "The authors propose a Bayesian approach to test the hypothesis that the sample behaves as a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "A metric used to quantify curve similarity.",
#       "entity_type": "metric",
#       "name": "total area between the sample and reference standard curves",
#       "quote": "We adopt this reformulated hypothesis in this article and propose that it can be tested in a straightforward manner by considering the total area between the sample and reference standard curves."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A method for comparing dose-response curves.",
#       "entity_type": "algorithm",
#       "name": "curve similarity method",
#       "quote": "We also present the curve similarity method, which uses the area between the two dose -response curves as a means of testing the hypothesis that the test sample behaves as a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "A statistical approach to hypothesis testing.",
#       "entity_type": "statistical_test",
#       "name": "frequentist hypothesis test",
#       "quote": "Two solutions are offered: the first is a frequentist hypothesis test and the second is a probabilistic approach using Bayes ' theorem."
#     },
#     {
#       "description": "A probabilistic approach to hypothesis testing.",
#       "entity_type": "statistical_test",
#       "name": "Bayes' theorem",
#       "quote": "Two solutions are offered: the first is a frequentist hypothesis test and the second is a probabilistic approach using Bayes ' theorem."
#     },
#      {
#       "description": "A statistical test for comparing curves.",
#       "entity_type": "statistical_test",
#       "name": "difference testing",
#       "quote": "We compare the curve similarity method (frequentist and Bayesian) to the traditional difference testing and equivalence approaches as well as to a recent frequentist test offered by Novick and Yang (2019)."
#     },
#     {
#       "description": "A statistical test for comparing curves.",
#        "entity_type": "statistical_test",
#       "name": "equivalence approaches",
#       "quote": "We compare the curve similarity method (frequentist and Bayesian) to the traditional difference testing and equivalence approaches as well as to a recent frequentist test offered by Novick and Yang (2019)."
#     },
#     {
#       "description": "A statistical test for comparing curves.",
#       "entity_type": "statistical_test",
#       "name": "Novick and Yang (2019)",
#       "quote": "We compare the curve similarity method (frequentist and Bayesian) to the traditional difference testing and equivalence approaches as well as to a recent frequentist test offered by Novick and Yang (2019)."
#     },
#     {
#       "description": "A mathematical representation of a dose-response curve.",
#       "entity_type": "model",
#       "name": "sigmoidal four parameter nonlinear logistic curve",
#       "quote": "As most bioassays are performed under log dilution, the sigmoidal four parameter nonlinear logistic curve used to model dose -response data is"
#     },
#     {
#       "description": "Parameter of the sigmoidal curve.",
#       "entity_type": "metric",
#       "name": "inflection point",
#       "quote": "The parameter ci represents the inflection point of the symmetric sigmoidal curve, bi and ai are the upper and lower asymptotes, and di is a slope-like factor."
#     },
#     {
#       "description": "Parameter of the sigmoidal curve.",
#        "entity_type": "metric",
#       "name": "upper asymptotes",
#       "quote": "The parameter ci represents the inflection point of the symmetric sigmoidal curve, bi and ai are the upper and lower asymptotes, and di is a slope-like factor."
#     },
#     {
#       "description": "Parameter of the sigmoidal curve.",
#        "entity_type": "metric",
#       "name": "lower asymptotes",
#       "quote": "The parameter ci represents the inflection point of the symmetric sigmoidal curve, bi and ai are the upper and lower asymptotes, and di is a slope-like factor."
#     },
#     {
#       "description": "Parameter of the sigmoidal curve.",
#        "entity_type": "metric",
#       "name": "slope-like factor",
#       "quote": "The parameter ci represents the inflection point of the symmetric sigmoidal curve, bi and ai are the upper and lower asymptotes, and di is a slope-like factor."
#     },
#     {
#       "description": "A statistical test for comparing curves.",
#       "entity_type": "statistical_test",
#       "name": "difference method",
#       "quote": "A common approach for assessing the parallelism of f θ 1 ; x ð Þ and f θ 2 ; x ð Þ is the difference method which tests the null hypothesis that H 0 : a 1 ¼ a 2 and b1 ¼ b2 and d 1 ¼ d 2 against H 1 : a 1 /C222 a 2 or b1 /C222 b2 or d 1 /C222 d 2 using the F -statistic"
#     },
#      {
#       "description": "A statistical test for comparing curves.",
#       "entity_type": "statistical_test",
#       "name": "F-statistic",
#       "quote": "A common approach for assessing the parallelism of f θ 1 ; x ð Þ and f θ 2 ; x ð Þ is the difference method which tests the null hypothesis that H 0 : a 1 ¼ a 2 and b1 ¼ b2 and d 1 ¼ d 2 against H 1 : a 1 /C222 a 2 or b1 /C222 b2 or d 1 /C222 d 2 using the F -statistic"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A statistical test used to compare the fit of two models.",
#       "entity_type": "statistical_test",
#       "name": "F-test",
#       "quote": "Many criticisms of the F -test approach to testing for parallelism have been raised in the literature"
#     },
#     {
#       "description": "A statistical hypothesis that assumes no difference between groups or models.",
#       "entity_type": "hypothesis",
#       "name": "null hypothesis",
#        "quote": "The null hypothesis is rejected if F is larger than the critical value from the F 3 ; 2 n /C0 8 1 /C0 α ð Þ distribution."
#     },
#      {
#       "description": "A statistical hypothesis that assumes a difference between groups or models.",
#       "entity_type": "hypothesis",
#       "name": "research hypothesis",
#        "quote": "Jonkman and Sidik (2009) proposed an approach where the research hypothesis ( H 1 Þ is that the curves are parallel"
#     },
#     {
#       "description": "A statistical distribution used in hypothesis testing.",
#       "entity_type": "distribution",
#       "name": "F distribution",
#       "quote": "The null hypothesis is rejected if F is larger than the critical value from the F 3 ; 2 n /C0 8 1 /C0 α ð Þ distribution."
#     },
#     {
#       "description": "A type of statistical model with 5 parameters.",
#       "entity_type": "model",
#       "name": "reduced parallel model",
#       "quote": "The test is carried out by comparing the fit of the ' reduced ' parallel model (5 parameters) to the fit of the ' full ' non-parallel model (8 parameters)."
#     },
#     {
#       "description": "A type of statistical model with 8 parameters.",
#       "entity_type": "model",
#       "name": "full non-parallel model",
#       "quote": "The test is carried out by comparing the fit of the ' reduced ' parallel model (5 parameters) to the fit of the ' full ' non-parallel model (8 parameters)."
#     },
#     {
#       "description": "A method for testing equivalence between models.",
#       "entity_type": "statistical_test",
#       "name": "equivalence test",
#       "quote": "If DL and DU denote practical equivalence margins, then the equivalence test in terms of unions and intersections is:"
#     },
#     {
#       "description": "A statistical test used to construct the intersection-union test.",
#       "entity_type": "statistical_test",
#       "name": "t-test",
#       "quote": "The standard approximate t -test is used to construct the intersection-union test."
#     },
#      {
#       "description": "A metric representing the sum of squared errors from fitting a model.",
#       "entity_type": "metric",
#       "name": "SSE",
#       "quote": "where SSE Reduced ð Þ is the sum of square errors from fitting (1) under H 0, SSE Full ð Þ is the sum of square errors from fitting (1) under H 1"
#     },
#     {
#       "description": "A metric representing the sum of squared errors from fitting a model under the null hypothesis.",
#       "entity_type": "metric",
#       "name": "SSE Reduced",
#       "quote": "where SSE Reduced ð Þ is the sum of square errors from fitting (1) under H 0"
#     },
#     {
#       "description": "A metric representing the sum of squared errors from fitting a model under the alternative hypothesis.",
#       "entity_type": "metric",
#       "name": "SSE Full",
#       "quote": "SSE Full ð Þ is the sum of square errors from fitting (1) under H 1"
#     },
#     {
#       "description": "A parameter in the model.",
#       "entity_type": "model",
#       "name": "a",
#       "quote": "H 0 : a 1 a 2 /C20 DL or a 1 a 2 /C21 DU or b 1 b 2 /C20 DL or b 1 b 2 /C21 DU or d 1 d 2 /C20 DL or d 1 d 2 /C21 DU"
#     },
#     {
#       "description": "A parameter in the model.",
#       "entity_type": "model",
#       "name": "b",
#       "quote": "H 0 : a 1 a 2 /C20 DL or a 1 a 2 /C21 DU or b 1 b 2 /C20 DL or b 1 b 2 /C21 DU or d 1 d 2 /C20 DL or d 1 d 2 /C21 DU"
#     },
#     {
#       "description": "A parameter in the model.",
#       "entity_type": "model",
#       "name": "d",
#       "quote": "H 0 : a 1 a 2 /C20 DL or a 1 a 2 /C21 DU or b 1 b 2 /C20 DL or b 1 b 2 /C21 DU or d 1 d 2 /C20 DL or d 1 d 2 /C21 DU"
#     },
#     {
#       "description": "A margin for practical equivalence.",
#       "entity_type": "metric",
#       "name": "DL",
#       "quote": "If DL and DU denote practical equivalence margins, then the equivalence test in terms of unions and intersections is:"
#     },
#     {
#       "description": "A margin for practical equivalence.",
#       "entity_type": "metric",
#       "name": "DU",
#       "quote": "If DL and DU denote practical equivalence margins, then the equivalence test in terms of unions and intersections is:"
#     },
#      {
#       "description": "A researcher in the field of statistics.",
#       "entity_type": "author",
#       "name": "Gottschalk",
#       "quote": "(see Gottschalk and Dunn 2005; Jonkman and Sidik 2009)."
#     },
#     {
#       "description": "A researcher in the field of statistics.",
#       "entity_type": "author",
#       "name": "Dunn",
#       "quote": "(see Gottschalk and Dunn 2005; Jonkman and Sidik 2009)."
#     },
#     {
#       "description": "A researcher in the field of statistics.",
#        "entity_type": "author",
#       "name": "Jonkman",
#       "quote": "(see Gottschalk and Dunn 2005; Jonkman and Sidik 2009)."
#     },
#     {
#       "description": "A researcher in the field of statistics.",
#        "entity_type": "author",
#       "name": "Sidik",
#       "quote": "(see Gottschalk and Dunn 2005; Jonkman and Sidik 2009)."
#     },
#     {
#       "description": "A researcher in the field of statistics.",
#        "entity_type": "author",
#       "name": "Hauck",
#       "quote": "(see, for example, Gottschalk and Dunn 2005; Hauck et al. 2005; Jonkman and Sidik 2009; Novick et al. 2012)."
#     },
#     {
#       "description": "A researcher in the field of statistics.",
#        "entity_type": "author",
#       "name": "Novick",
#       "quote": "(see, for example, Gottschalk and Dunn 2005; Hauck et al. 2005; Jonkman and Sidik 2009; Novick et al. 2012)."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "statistical hypothesis test",
#       "entity_type": "hypothesis",
#       "name": "H 0 : a 1 /C0 DLa 2 /C20 0",
#       "quote": "The first of the six hypothesis tests, which can be rewritten as H 0 : a 1 /C0 DLa 2 /C20 0 versus H 1 : a 1 /C0 DLa 2 > 0, uses the test statistic"
#     },
#     {
#       "description": "statistical hypothesis test",
#       "entity_type": "hypothesis",
#       "name": "H 1 : a 1 /C0 DLa 2 > 0",
#       "quote": "The first of the six hypothesis tests, which can be rewritten as H 0 : a 1 /C0 DLa 2 /C20 0 versus H 1 : a 1 /C0 DLa 2 > 0, uses the test statistic"
#     },
#      {
#       "description": "statistical test",
#       "entity_type": "statistical_test",
#       "name": "T 1",
#       "quote": "The first of the six hypothesis tests, which can be rewritten as H 0 : a 1 /C0 DLa 2 /C20 0 versus H 1 : a 1 /C0 DLa 2 > 0, uses the test statistic T 1 ¼ ^ a 1 /C0 DL ^ a 2 s : e : ^ a 1 /C0 DL ^ a 2 ð Þ"
#     },
#     {
#       "description": "statistical test",
#       "entity_type": "statistical_test",
#       "name": "t 2 n /C0 8 ; α",
#       "quote": "The null hypothesis is rejected if T 1 > t 2 n /C0 8 ; α"
#     },
#     {
#       "description": "statistical hypothesis test",
#        "entity_type": "hypothesis",
#       "name": "H 0 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j /C21 γ",
#       "quote": "Rather than focusing on the similarity of model parameters, Novick et al. (2012) propose a Bayesian approach for testing the hypothesis that the test sample is a dilution or concentration of the reference standard: H 0 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j /C21 γ versus H 1 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j < γ ; (3)"
#     },
#     {
#       "description": "statistical hypothesis test",
#       "entity_type": "hypothesis",
#       "name": "H 1 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j < γ",
#       "quote": "Rather than focusing on the similarity of model parameters, Novick et al. (2012) propose a Bayesian approach for testing the hypothesis that the test sample is a dilution or concentration of the reference standard: H 0 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j /C21 γ versus H 1 : min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j < γ ; (3)"
#     },
#     {
#       "description": "metric",
#       "entity_type": "metric",
#       "name": "p γ ; xL ; xU ð Þ",
#       "quote": "The proposed metric to measure parallel equivalence is the Bayesian posterior probability p γ ; xL ; xU ð Þ ¼ Pr min ρ max x 2 xL ; xU ½ /C138 f θ 1 ; x ð Þ /C0 f θ 2 ; x þ ρ ð Þ j j < γ j data /C26 /C27"
#     },
#     {
#       "description": "algorithm",
#       "entity_type": "algorithm",
#       "name": "Bayesian approach",
#       "quote": "Rather than focusing on the similarity of model parameters, Novick et al. (2012) propose a Bayesian approach for testing the hypothesis that the test sample is a dilution or concentration of the reference standard"
#     },
#      {
#       "description": "author",
#       "entity_type": "author",
#       "name": "Novick et al.",
#       "quote": "Rather than focusing on the similarity of model parameters, Novick et al. (2012) propose a Bayesian approach for testing the hypothesis that the test sample is a dilution or concentration of the reference standard"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A mathematical model with four parameters",
#       "entity_type": "model",
#       "name": "4PL model",
#       "quote": "Since a closedform solution to (3) does not exist in the case of the 4PL model, the authors propose a minimax search algorithm which involves a two-dimensional grid search on x and ρ"
#     },
#     {
#       "description": "A search algorithm to find the minimum of a maximum value",
#       "entity_type": "algorithm",
#       "name": "minimax search algorithm",
#       "quote": "the authors propose a minimax search algorithm which involves a two-dimensional grid search on x and ρ"
#     },
#      {
#       "description": "A statistical approach that uses prior knowledge",
#       "entity_type": "statistical_test",
#       "name": "Bayesian approach",
#       "quote": "An advantage of the Bayesian approach is the fact that the statistical power of the test could be increased by incorporating prior knowledge of parameter values into the construction of the prior distributions."
#     },
#     {
#       "description": "A simulation method for sampling from probability distributions",
#       "entity_type": "algorithm",
#       "name": "Markov chain Monte Carlo simulation",
#        "quote": "One drawback of the parallel equivalence approach is the fact that it requires a Markov chain Monte Carlo simulation to be executed for every plate of every assay."
#     },
#     {
#       "description": "A statistical approach that uses observed data",
#       "entity_type": "statistical_test",
#       "name": "frequentist approach",
#       "quote": "Novick and Yang (2019) recently proposed a frequentist approach to testing the hypothesis in (3) where the standard error of the difference f ^ θ 1 ; x /C16 /C17 /C0 f ^ θ 2 ; x þ ρ /C16 /C17 is approximated via the delta method, conditioned on a fixed point estimate for ρ"
#     },
#     {
#       "description": "A method for approximating the variance of a function",
#       "entity_type": "algorithm",
#       "name": "delta method",
#       "quote": "the standard error of the difference f ^ θ 1 ; x /C16 /C17 /C0 f ^ θ 2 ; x þ ρ /C16 /C17 is approximated via the delta method, conditioned on a fixed point estimate for ρ"
#     },
#     {
#       "description": "A measure of the spread of data",
#       "entity_type": "metric",
#       "name": "standard error",
#       "quote": "where the standard error of the difference f ^ θ 1 ; x /C16 /C17 /C0 f ^ θ 2 ; x þ ρ /C16 /C17 is approximated via the delta method"
#     },
#      {
#       "description": "A statistical test to determine if two groups are equivalent",
#       "entity_type": "hypothesis",
#       "name": "equivalence test",
#       "quote": "Conditioned on the pair ( x ¼ x /C3 ; ρ ¼ ^ ρ Þ found using a minimax algorithm, equivalence is declared with significance level α if Pr T 2 n /C0 p < ^ γ /C0 γ SE γ /C16 /C17 < α"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "Authors of a paper on Bayesian approach",
#       "entity_type": "author",
#       "name": "Novick et al.",
#       "quote": "the Bayesian approach presented by Novick et al. (2012)"
#     },
#     {
#       "description": "Year of publication of a paper",
#       "entity_type": "paper",
#       "name": "2012",
#       "quote": "Novick et al. (2012)"
#     },
#      {
#       "description": "Authors of a paper on Bayesian approach",
#       "entity_type": "author",
#       "name": "Novick and Yang",
#       "quote": "as Novick and Yang (2019) point out"
#     },
#     {
#       "description": "Year of publication of a paper",
#       "entity_type": "paper",
#       "name": "2019",
#       "quote": "Novick and Yang (2019)"
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "metric",
#       "name": "ρ",
#       "quote": "the posterior distribution for ρ is resolved via the frequentist approach"
#     },
#     {
#       "description": "A parameter in the model",
#        "entity_type": "metric",
#       "name": "γ",
#       "quote": "the choice of the equivalence bound, γ , remains a challenge."
#     },
#     {
#       "description": "A statistical distribution",
#       "entity_type": "distribution",
#       "name": "Gumbel distribution",
#       "quote": "fitting the results of γ 95 ¼ max LCL x /C3 ð Þ j j ; UCL x /C3 ð Þ j j ð Þ to the Gumbel distribution"
#     },
#     {
#       "description": "Lower confidence limit",
#       "entity_type": "metric",
#       "name": "LCL",
#       "quote": "LCL x ðÞ¼ f ^ θ 1 ; x /C3 /C16 /C17 /C0 f ^ θ 2 ; x /C3 þ ^ ρ /C16 /C17 /C0 T 1 /C0 α ; 2 n /C0 p ð Þ /C2 SE γ"
#     },
#     {
#       "description": "Upper confidence limit",
#       "entity_type": "metric",
#       "name": "UCL",
#       "quote": "UCL x ðÞ¼ f ^ θ 1 ; x /C3 /C16 /C17 /C0 f ^ θ 2 ; x /C3 þ ^ ρ /C16 /C17 þ T 1 /C0 α ; 2 n /C0 p ð Þ /C2 SE γ"
#     },
#     {
#       "description": "A statistical hypothesis",
#       "entity_type": "hypothesis",
#       "name": "curve similarity",
#       "quote": "we introduce a straightforward curve similarity approach to testing the hypothesis that the test sample curve behaves like a dilution or concentration of the reference standard."
#     },
#      {
#       "description": "A function",
#       "entity_type": "model",
#       "name": "f θ 1 ; x ð Þ",
#       "quote": "the parallelism of two curves, f θ 1 ; x ð Þ and f θ 2 ; x ð Þ by means of curve similarity"
#     },
#     {
#       "description": "A function",
#       "entity_type": "model",
#       "name": "f θ 2 ; x ð Þ",
#       "quote": "the parallelism of two curves, f θ 1 ; x ð Þ and f θ 2 ; x ð Þ by means of curve similarity"
#     },
#     {
#       "description": "Concentrations",
#       "entity_type": "metric",
#       "name": "x",
#       "quote": "For a set of concentrations x 1 /C20 ... /C20 xn"
#     },
#     {
#       "description": "Response data",
#       "entity_type": "metric",
#       "name": "yij",
#       "quote": "theresponsedata, yij ¼ f θ i ; xj /C0 /C1 þ eij"
#     },
#     {
#       "description": "Error term",
#       "entity_type": "metric",
#       "name": "eij",
#       "quote": "where eij , N 0 ; σ 2 ij /C16 /C17 ,for j ¼ 1 ; ... ; n"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "σ ij",
#       "quote": "Wefurtherassumethat σ ij ¼ f θ i ; xj /C0 /C1 /C2 ν ,where ν denotes the %CV/ 100."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "ν",
#       "quote": "Wefurtherassumethat σ ij ¼ f θ i ; xj /C0 /C1 /C2 ν ,where ν denotes the %CV/ 100."
#     },
#      {
#       "description": "A statistical concept",
#       "entity_type": "metric",
#       "name": "%CV",
#       "quote": "Wefurtherassumethat σ ij ¼ f θ i ; xj /C0 /C1 /C2 ν ,where ν denotes the %CV/ 100."
#     },
#     {
#       "description": "A statistical concept",
#       "entity_type": "model",
#       "name": "mean variance structure",
#        "quote": "Note that the power of the mean variance structure (see Carroll 2003 and Gottschalk and Dunn, 2005), is also commonly used to model the functional dependence of response variance for bioassay."
#     },
#     {
#       "description": "An author",
#       "entity_type": "author",
#       "name": "Carroll",
#       "quote": "Note that the power of the mean variance structure (see Carroll 2003 and Gottschalk and Dunn, 2005), is also commonly used to model the functional dependence of response variance for bioassay."
#     },
#     {
#       "description": "An author",
#       "entity_type": "author",
#       "name": "Gottschalk and Dunn",
#        "quote": "Note that the power of the mean variance structure (see Carroll 2003 and Gottschalk and Dunn, 2005), is also commonly used to model the functional dependence of response variance for bioassay."
#     },
#     {
#       "description": "A statistical method",
#       "entity_type": "algorithm",
#       "name": "ordinary least squares estimators",
#       "quote": "Let ^ θ 1 ; ^ θ 2 /C16 /C17 denote the ordinary least squares estimators for θ 1 ; θ 2 ð Þ ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "θ 1",
#       "quote": "Let ^ θ 1 ; ^ θ 2 /C16 /C17 denote the ordinary least squares estimators for θ 1 ; θ 2 ð Þ ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "θ 2",
#       "quote": "Let ^ θ 1 ; ^ θ 2 /C16 /C17 denote the ordinary least squares estimators for θ 1 ; θ 2 ð Þ ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "c 1",
#       "quote": "First,theinflectionpointsofthetwofittedcurves are aligned such that ^ c 1 ¼ ^ c 2 ¼ EC 50, the half maximal effective concentration."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "c 2",
#       "quote": "First,theinflectionpointsofthetwofittedcurves are aligned such that ^ c 1 ¼ ^ c 2 ¼ EC 50, the half maximal effective concentration."
#     },
#     {
#       "description": "A metric",
#       "entity_type": "metric",
#       "name": "EC 50",
#       "quote": "First,theinflectionpointsofthetwofittedcurves are aligned such that ^ c 1 ¼ ^ c 2 ¼ EC 50, the half maximal effective concentration."
#     },
#      {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "a 1",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "b 1",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "d 1",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "a 2",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "b 2",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "d 2",
#       "quote": "That is, ^ θ 1 ¼ ^ a 1 ; ^ b 1 ; ^ c 1 ; ^ d 1 /C16 /C17 and ^ θ /C3 2 ¼ ^ a 2 ; ^ b 2 ; ^ c 1 ; ^ d 2 /C16 /C17 ."
#     },
#     {
#       "description": "A metric",
#       "entity_type": "metric",
#       "name": "κ",
#       "quote": "Thetotalareabetweenthetwofittedcurvesis κ ^ θ 1 ; ^ θ /C3 2 /C16 /C17 ¼ ð xU xL max f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o /C0 min f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o h i dx"
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "xU",
#       "quote": "κ ^ θ 1 ; ^ θ /C3 2 /C16 /C17 ¼ ð xU xL max f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o /C0 min f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o h i dx"
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "xL",
#       "quote": "κ ^ θ 1 ; ^ θ /C3 2 /C16 /C17 ¼ ð xU xL max f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o /C0 min f ^ θ 1 ; x /C16 /C17 ; f ^ θ /C3 2 ; x /C16 /C17 n o h i dx"
#     },
#     {
#       "description": "A parameter in the model",
#       "entity_type": "model",
#       "name": "b θ",
#       "quote": "where b θ ¼ ^ θ 1 ; ^ θ /C3 2 /C16 /C17 . For this work, we set xL ¼ x 1 and xU ¼ xn which is consistent with the approach taken by Novick and Yang (2019) to calculate the parallel equivalence metric."
#     },
#     {
#       "description": "An author",
#       "entity_type": "author",
#       "name": "Novick and Yang",
#       "quote": "For this work, we set xL ¼ x 1 and xU ¼ xn which is consistent with the approach taken by Novick and Yang (2019) to calculate the parallel equivalence metric."
#     },
#     {
#       "description": "A metric",
#       "entity_type": "metric",
#       "name": "parallel equivalence metric",
#       "quote": "For this work, we set xL ¼ x 1 and xU ¼ xn which is consistent with the approach taken by Novick and Yang (2019) to calculate the parallel equivalence metric."
#     },
#     {
#       "description": "A statistical method",
#       "entity_type": "algorithm",
#       "name": "trapezoidal rule",
#       "quote": "Although there is no closed form solution to (4), the integral can be approximated using the trapezoidal rule (see Yeh 2002), where xL ; xU ½ /C138 is divided into m subintervals of width xU /C0 xL ð Þ = m ."
#     },
#     {
#       "description": "An author",
#       "entity_type": "author",
#       "name": "Yeh",
#       "quote": "Although there is no closed form solution to (4), the integral can be approximated using the trapezoidal rule (see Yeh 2002), where xL ; xU ½ /C138 is divided into m subintervals of width xU /C0 xL ð Þ = m ."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "Mathematical expression",
#       "entity_type": "model",
#       "name": "A b θ /C16 /C17",
#       "quote": "A b θ /C16 /C17 ¼ xU /C0 xL m g b θ ; xL /C16 /C17 þ g b θ ; xU /C16 /C17 2 þ X m /C0 1 k ¼ 1 g b θ ; xL þ kxU /C0 xL ð Þ m /C18 /C19 2 4 3 5 (5)"
#     },
#     {
#       "description": "Mathematical expression for variance",
#       "entity_type": "model",
#       "name": "Var A b θ /C16 /C17",
#       "quote": "Var A b θ /C16 /C17 h i ¼ xU /C0 xL m /C16 /C17 2 X m i ¼ 0 Var hi b θ /C16 /C17 h i þ 2 X m /C0 1 k ¼ 0 X m q ¼ k þ 1 Cov hk b θ /C16 /C17 ; hq b θ /C16 /C17 h i 8 < : 9 = ; : (6)"
#     },
#     {
#       "description": "Mathematical expression",
#       "entity_type": "model",
#       "name": "h 0 b θ /C16 /C17",
#       "quote": "Let h 0 b θ /C16 /C17 ¼ 1 2 g b θ ; xL /C16 /C17"
#     },
#      {
#       "description": "Mathematical expression",
#       "entity_type": "model",
#       "name": "hm b θ /C16 /C17",
#       "quote": "hm b θ /C16 /C17 ¼ 1 2 g b θ ; xU /C16 /C17"
#     },
#     {
#       "description": "Mathematical expression",
#       "entity_type": "model",
#       "name": "hk b θ /C16 /C17",
#       "quote": "hk b θ /C16 /C17 ¼ g b θ ; xL þ kxU /C0 xL ð Þ m /C16 /C17"
#     },
#     {
#       "description": "Statistical theorem",
#       "entity_type": "statistical_test",
#       "name": "Theorem A",
#       "quote": "By Theorem A in Serfling (1980), hk b θ /C16 /C17 , AN hk θ ðÞ ; Var hk b θ /C16 /C17 h i n o"
#     },
#     {
#       "description": "Mathematical expression",
#        "entity_type": "model",
#       "name": "A b θ /C16/C17",
#       "quote": "Itfollowsthat A b θ /C16/C17 , AN A θ ðÞ ; Var A b θ /C16/C17 h i n o"
#     },
#     {
#       "description": "Statistical method",
#       "entity_type": "algorithm",
#       "name": "delta method",
#       "quote": "The variance and covariance components in (6) can be approximated using the delta method."
#     },
#     {
#       "description": "Mathematical expression",
#       "entity_type": "model",
#       "name": "λ b θ /C16 /C17",
#       "quote": "λ b θ /C16 /C17 ¼ 1 /C0 κ b θ /C16 /C17 η ; (7)"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A baseline area used for normalization",
#       "entity_type": "metric",
#       "name": "η",
#       "quote": "where η is some baseline area such that η /C21 κ b θ /C16 /C17"
#     },
#     {
#       "description": "A measure of curve similarity",
#       "entity_type": "metric",
#       "name": "λ θ",
#       "quote": "Thus, λ θ ð Þ 2 0 ; 1 ½ /C138 represents a percent area of curve similarity."
#     },
#      {
#       "description": "A parameter related to the curve",
#       "entity_type": "metric",
#       "name": "κ b θ",
#       "quote": "By (5) and (6), λ b θ /C16 /C17 , AN A θ ðÞ ; 1 η 2 Var A b θ /C16 /C17 h i n o"
#     },
#     {
#       "description": "A parameter related to the curve",
#       "entity_type": "metric",
#       "name": "κθ",
#       "quote": "The shaded region is κθ 1 ; θ /C3 2 /C0 /C1 and the dotted rectangle is the normalizing baseline, η"
#     },
#     {
#       "description": "A statistical hypothesis",
#       "entity_type": "hypothesis",
#       "name": "H 0",
#       "quote": "H 0 : λ θ ð Þ /C20 δ versus H 1 : λ θ ð Þ > δ : (8)"
#     },
#     {
#       "description": "A statistical hypothesis",
#        "entity_type": "hypothesis",
#       "name": "H 1",
#       "quote": "H 0 : λ θ ð Þ /C20 δ versus H 1 : λ θ ð Þ > δ : (8)"
#     },
#      {
#       "description": "A statistical test",
#       "entity_type": "statistical_test",
#       "name": "equivalence testing",
#       "quote": "Consistent with the paradigm of equivalence testing, the two curves are considered parallel if the null hypothesis is rejected:"
#     },
#     {
#       "description": "A parameter related to the curve",
#       "entity_type": "metric",
#       "name": "EC 50",
#       "quote": "Figure 1(b) provides an example of how the two curves from Figure 1(a) originally fit to (1) are shifted horizontally to align at the EC 50 value."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "Hypothesis test for equivalence between dose-response curves",
#       "entity_type": "hypothesis",
#       "name": "hypothesis test in (8)",
#       "quote": "The hypothesis test in (8) is formulated with the purpose of testing equivalence between two dose -response curves by assessing whether the sample behaves as a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "Concept of testing if a sample is a dilution or concentration of a reference standard",
#       "entity_type": "hypothesis",
#       "name": "dilution or concentration",
#       "quote": "testing equivalence between two dose -response curves by assessing whether the sample behaves as a dilution or concentration of the reference standard."
#     },
#     {
#       "description": "Concept of comparing curve shapes to test for dilutional similarity",
#       "entity_type": "hypothesis",
#       "name": "dilutional similarity",
#       "quote": "Dilutional similarity is directly tested via a comparison of curve shapes."
#     },
#      {
#       "description": "Formula for standard error",
#       "entity_type": "metric",
#       "name": "SE",
#       "quote": "SE ¼ ffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffiffi 1 η 2 Var A b θ /C16 /C17 h i r"
#     },
#     {
#       "description": "Statistical test for similarity",
#       "entity_type": "statistical_test",
#       "name": "similarity test",
#       "quote": "Similarity is declared ( H 1 Þ with significance level α if p -value ¼ Pr T 2 n /C0 p > λ b θ /C0 /C1 /C0 δ SE /C18 /C19 < α"
#     },
#     {
#       "description": "Significance level for the similarity test",
#       "entity_type": "metric",
#       "name": "α",
#       "quote": "Similarity is declared ( H 1 Þ with significance level α if p -value ¼ Pr T 2 n /C0 p > λ b θ /C0 /C1 /C0 δ SE /C18 /C19 < α"
#     },
#     {
#       "description": "Method for curve similarity",
#       "entity_type": "algorithm",
#       "name": "Novick and Yang (2019) method",
#       "quote": "similarity approach are less straightforward than the Novick and Yang (2019) method under the frequentist approach."
#     },
#     {
#       "description": "Bayesian implementation of curve similarity metric",
#        "entity_type": "algorithm",
#       "name": "Bayesian implementation of the curve similarity metric",
#       "quote": "we find that the Bayesian implementation of the curve similarity metric (Section 2.3) is less complex and less computationally intensive than that of the Novick and Yang (2019) method."
#     },
#     {
#       "description": "Bayesian posterior probability as a metric",
#       "entity_type": "metric",
#       "name": "Bayesian posterior probability",
#       "quote": "A Bayesian posterior probability could be used as a metric to test (8)."
#     },
#     {
#       "description": "Probability of rejecting the null hypothesis",
#       "entity_type": "metric",
#       "name": "p(δ; θ1; θ2)",
#       "quote": "The probability of rejecting H 0 is p δ ; θ 1 ; θ 2 ð Þ ¼ Pr λ θ ð Þ > δ j data f g"
#     },
#     {
#       "description": "Threshold for rejecting the null hypothesis",
#       "entity_type": "metric",
#       "name": "p0",
#       "quote": "The decision to reject H 0 can be made if p δ ; θ 1 ; θ 2 ð Þ > p 0."
#     },
#     {
#       "description": "Bayes' theorem for deriving posterior distributions",
#       "entity_type": "algorithm",
#       "name": "Bayes' theorem",
#       "quote": "Theposteriordistributionsfor θ 1, θ 2,arederived via Bayes ' theorem using prior distributions on the modelparametersandthelikelihoodofthe"
#     },
#     {
#       "description": "Likelihood function",
#       "entity_type": "metric",
#       "name": "l",
#       "quote": "where l /C1 ðÞ is the likelihood function and x and y denote the data vectors."
#     },
#     {
#       "description": "Prior distribution for model parameters",
#       "entity_type": "distribution",
#       "name": "π(θi)",
#       "quote": "The vague prior distributions are πθ i ð Þ ¼ N 0 ; 31 : 6 2 ð Þ I θ i > 0 f g"
#     },
#     {
#       "description": "Prior distribution for a parameter",
#       "entity_type": "distribution",
#       "name": "π(ν)",
#       "quote": "and πν ðÞ¼ U 0 ; 1 ð Þ"
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": "A parameter in a dose-response model",
#       "entity_type": "model",
#       "name": "θ i",
#       "quote": "It is reasonable to truncate the prior for θ i since the analyst knows a priori whether the dose -response relationship is inhibitive or stimulating"
#     },
#     {
#       "description": "A parameter in a dose-response model",
#       "entity_type": "model",
#       "name": "θ 1",
#       "quote": "The posterior probability p δ ; θ 1 ; θ 2 ð Þ is the proportion of random draws from the posterior distributions of θ 1 and θ 2 that result in λθ 1 ; θ /C3 2 /C0 /C1 > δ"
#     },
#     {
#       "description": "A parameter in a dose-response model",
#       "entity_type": "model",
#       "name": "θ 2",
#       "quote": "The posterior probability p δ ; θ 1 ; θ 2 ð Þ is the proportion of random draws from the posterior distributions of θ 1 and θ 2 that result in λθ 1 ; θ /C3 2 /C0 /C1 > δ"
#     },
#      {
#       "description": "A parameter in a dose-response model",
#       "entity_type": "model",
#       "name": "λθ 1 ; θ /C3 2 /C0 /C1",
#       "quote": "The posterior probability p δ ; θ 1 ; θ 2 ð Þ is the proportion of random draws from the posterior distributions of θ 1 and θ 2 that result in λθ 1 ; θ /C3 2 /C0 /C1 > δ"
#     },
#     {
#       "description": "A threshold value",
#       "entity_type": "metric",
#       "name": "δ",
#       "quote": "The posterior probability p δ ; θ 1 ; θ 2 ð Þ is the proportion of random draws from the posterior distributions of θ 1 and θ 2 that result in λθ 1 ; θ /C3 2 /C0 /C1 > δ"
#     },
#     {
#       "description": "A probability distribution",
#       "entity_type": "distribution",
#       "name": "πθ 1 j x ; y ð Þ",
#       "quote": "p δ ; θ 1 ; θ 2 ð Þ ¼ 1 r X r I ðð λθ 1 ; θ /C3 2 /C0 /C1 πθ 1 j x ; y ð Þ πθ 2 j x ; y ð Þ d θ 1 d θ 2 > δ /C26 /C27"
#     },
#      {
#       "description": "A probability distribution",
#       "entity_type": "distribution",
#       "name": "πθ 2 j x ; y ð Þ",
#       "quote": "p δ ; θ 1 ; θ 2 ð Þ ¼ 1 r X r I ðð λθ 1 ; θ /C3 2 /C0 /C1 πθ 1 j x ; y ð Þ πθ 2 j x ; y ð Þ d θ 1 d θ 2 > δ /C26 /C27"
#     },
#     {
#       "description": "A parameter in a dose-response model",
#       "entity_type": "model",
#       "name": "η",
#       "quote": "Note that the posterior distribution for λθ 1 ; θ /C3 2 /C0 /C1 assumes a fixed value for η , consistent with the approach used to approximate the variance for λθ 1 ; θ /C3 2 /C0 /C1 under the frequentist method."
#     },
#     {
#       "description": "A statistical method",
#       "entity_type": "algorithm",
#       "name": "Bayesian approach",
#       "quote": "The main advantages and drawbacks of adopting the Bayesian approach are similar to those of the parallel equivalence method described in Section 2.1."
#     },
#     {
#       "description": "A statistical method",
#        "entity_type": "algorithm",
#       "name": "frequentist method",
#       "quote": "Note that the posterior distribution for λθ 1 ; θ /C3 2 /C0 /C1 assumes a fixed value for η , consistent with the approach used to approximate the variance for λθ 1 ; θ /C3 2 /C0 /C1 under the frequentist method."
#     },
#     {
#       "description": "A statistical method",
#       "entity_type": "algorithm",
#       "name": "parallel equivalence method",
#       "quote": "The main advantages and drawbacks of adopting the Bayesian approach are similar to those of the parallel equivalence method described in Section 2.1."
#     },
#      {
#       "description": "A statistical theorem",
#       "entity_type": "algorithm",
# ...
#       "entity_type": "statistical_test",
#       "name": "equivalence test",
#       "quote": "The properties of the curve similarity approach were evaluated and compared to those of the equivalence and difference tests"
#     },
#     {
#       "description": "A statistical test used for comparison.",
#       "entity_type": "statistical_test",
#        "name": "difference test",
#       "quote": "The properties of the curve similarity approach were evaluated and compared to those of the equivalence and difference tests"
#     },
#     {
#       "description": "A frequentist method used for comparison.",
#       "entity_type": "algorithm",
#       "name": "NY frequentist method",
#       "quote": "The properties of the curve similarity approach were evaluated and compared to those of the equivalence and difference tests as well as the NY frequentist method through a simulation study."
#     },
#     {
#       "description": "A study using simulations to evaluate the curve similarity approach.",
#       "entity_type": "dataset",
#       "name": "simulation study",
#       "quote": "The properties of the curve similarity approach were evaluated and compared to those of the equivalence and difference tests as well as the NY frequentist method through a simulation study."
#     },
#     {
#       "description": "A metric based on the area between curves.",
#       "entity_type": "metric",
#       "name": "CS metric",
#       "quote": "the concept of area between curves and the metric, 0 /C20 λθ 1 ; θ 2 ð Þ /C20 1, are more intuitive for scientists to grasp than the NY measures. Also, the computation of the CS metric is not dependent on an optimization routine, which can be a challenge of the NY approach."
#     },
#     {
#       "description": "A concentration-response model.",
#       "entity_type": "model",
#       "name": "5PL",
#       "quote": "Future research may involve adapting the CS metric to test for parallelism under other concentration-response models such as the 5PL and Gompertz."
#     },
#     {
#       "description": "A concentration-response model.",
#        "entity_type": "model",
#       "name": "Gompertz",
#       "quote": "Future research may involve adapting the CS metric to test for parallelism under other concentration-response models such as the 5PL and Gompertz."
#     },
#     {
#       "description": "A research hypothesis of similarity between curves.",
#       "entity_type": "hypothesis",
#       "name": "research hypothesis of similarity",
#       "quote": "adopting a research hypothesis of similarity ensures that sound scientific evidence leads to a conclusion of parallelism (rejection of H 0)."
#     },
#      {
#       "description": "A statistical hypothesis.",
#       "entity_type": "hypothesis",
#       "name": "H0",
#       "quote": "adopting a research hypothesis of similarity ensures that sound scientific evidence leads to a conclusion of parallelism (rejection of H 0)."
#     },
#     {
#       "description": "A statistical hypothesis.",
#       "entity_type": "hypothesis",
#       "name": "H1",
#       "quote": "we found that the CS method exhibited power levels closer to the theoretical α level than the NY approach at the H 0 = H 1 border."
#     },
#      {
#       "description": "A statistical concept.",
#       "entity_type": "metric",
#       "name": "power levels",
#       "quote": "we found that the CS method exhibited power levels closer to the theoretical α level than the NY approach at the H 0 = H 1 border."
#     },
#     {
#       "description": "A statistical concept.",
#       "entity_type": "metric",
#       "name": "α level",
#       "quote": "we found that the CS method exhibited power levels closer to the theoretical α level than the NY approach at the H 0 = H 1 border."
#     },
#     {
#       "description": "Author of a reference.",
#       "entity_type": "author",
#       "name": "Carroll, R. J.",
#       "quote": "Carroll, R. J. 2003."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Variances are not always nuisance parameters",
#       "quote": "Variances are not always nuisance parameters. Biometrics 59 (2):211 -220."
#     },
#     {
#       "description": null,
#       "entity_type": "institution",
#       "name": "European Directorate for the Quality of Medicines (EDQM)",
#       "quote": "European Directorate for the Quality of Medicines (EDQM). 2019. 5.3.Statistical analysis of results of biological assays and tests."
#     },
#      {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Statistical analysis of results of biological assays and tests",
#       "quote": "5.3.Statistical analysis of results of biological assays and tests. In European pharmacopeia 9.2 , 4353 -4381."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Gottschalk, P. G.",
#       "quote": "- Gottschalk, P. G., and J. R. Dunn. 2005. Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Dunn, J. R.",
#       "quote": "Gottschalk, P. G., and J. R. Dunn. 2005. Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#        "name": "Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data",
#       "quote": "Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data. Journal of Biopharmaceutical Statistics 15 (3):437 -463."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Hauck, W. W.",
#       "quote": "- Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Capen, R. C.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Callahan, J. D.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "De Muth, J. E.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Hsu, H.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Lansky, D.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Weisman, D.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Seaver, S. S.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#      {
#       "description": null,
#       "entity_type": "author",
#       "name": "Singer, R. R.",
#       "quote": "Hauck, W. W., R. C. Capen, J. D. Callahan, J. E. De Muth, H. Hsu, D. Lansky, D. Weisman, S. S. Seaver, R. R. Singer, and D. Weisman. 2005. Assessing parallelism prior to determining relative potency."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Assessing parallelism prior to determining relative potency",
#       "quote": "Assessing parallelism prior to determining relative potency. PDA Journal of Pharmaceutical Science and Technology 59 (2):127 -137."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Jonkman, J. N.",
#       "quote": "- Jonkman, J. N., and K. Sidik. 2009. Equivalence testing for parallelism in the four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Sidik, K.",
#       "quote": "Jonkman, J. N., and K. Sidik. 2009. Equivalence testing for parallelism in the four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Equivalence testing for parallelism in the four-parameter logistic model",
#       "quote": "Equivalence testing for parallelism in the four-parameter logistic model. Journal of Biopharmaceutical Statistics 19 (5):818 -837."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Novick, S.",
#       "quote": "- Novick, S., and H. Yang. 2019. A fast and reliable test for parallelism in bioassay."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Yang, H.",
#       "quote": "- Novick, S., and H. Yang. 2019. A fast and reliable test for parallelism in bioassay."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "A fast and reliable test for parallelism in bioassay",
#       "quote": "A fast and reliable test for parallelism in bioassay. Journal of Biopharmaceutical Statistics 29 (6):1011 -1023."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Novick, S. J.",
#       "quote": "- Novick, S. J., H. Yang, and J. J. Peterson. 2012. A Bayesian approach to parallelism testing in bioassay."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Peterson, J. J.",
#       "quote": "Novick, S. J., H. Yang, and J. J. Peterson. 2012. A Bayesian approach to parallelism testing in bioassay."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "A Bayesian approach to parallelism testing in bioassay",
#       "quote": "A Bayesian approach to parallelism testing in bioassay. Statistics in Biopharmaceutical Research 4 (4):357 -374."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Serfling, R. J.",
#       "quote": "- Serfling, R. J. 1980. Approximation theorems of mathematical statistics ."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Approximation theorems of mathematical statistics",
#       "quote": "Approximation theorems of mathematical statistics ."
#     },
#      {
#       "description": null,
#       "entity_type": "model",
#       "name": "four-parameter logistic model",
#       "quote": "Equivalence testing for parallelism in the four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "statistical_test",
#       "name": "parallelism testing",
#       "quote": "A Bayesian approach to parallelism testing in bioassay."
#     },
#     {
#       "description": null,
#       "entity_type": "statistical_test",
#       "name": "equivalence testing",
#       "quote": "Equivalence testing for parallelism in the four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "metric",
#       "name": "relative potency",
#       "quote": "Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data."
#     },
#     {
#       "description": null,
#       "entity_type": "metric",
#       "name": "parallelism",
#       "quote": "Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data."
#     },
#     {
#       "description": null,
#       "entity_type": "metric",
#       "name": "linearity",
#       "quote": "Measuring parallelism, linearity, and relative potency in bioassay and immunoassay data."
#     },
#     {
#       "description": null,
#       "entity_type": "algorithm",
#       "name": "Bayesian approach",
#       "quote": "A Bayesian approach to parallelism testing in bioassay."
#     }
#   ]
# }{
#   "entities": [
#     {
#       "description": null,
#       "entity_type": "institution",
#       "name": "John Wiley & Sons",
#       "quote": "New York, NY: John Wiley & Sons."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Sidik, K.",
#       "quote": "- Sidik, K., and J. N. Jonkman."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "J. N. Jonkman",
#       "quote": "- Sidik, K., and J. N. Jonkman."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Testing for parallelism in the heteroscedastic four-parameter logistic model",
#       "quote": "Testing for parallelism in the heteroscedastic four-parameter logistic model. Journal of Biopharmaceutical Statistics 26 (2):250 -268."
#     },
#      {
#       "description": null,
#       "entity_type": "statistical_test",
#       "name": "parallelism testing",
#       "quote": "Testing for parallelism in the heteroscedastic four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "model",
#       "name": "heteroscedastic four-parameter logistic model",
#       "quote": "Testing for parallelism in the heteroscedastic four-parameter logistic model."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Journal of Biopharmaceutical Statistics",
#       "quote": "Journal of Biopharmaceutical Statistics 26 (2):250 -268."
#     },
#     {
#       "description": null,
#       "entity_type": "institution",
#       "name": "U.S. Pharmacopeial Convention",
#       "quote": "- U.S. Pharmacopeial Convention."
#     },
#     {
#       "description": null,
#        "entity_type": "paper",
#       "name": "1032 design and development of biological assays",
#       "quote": "1032 design and development of biological assays. USP 35-NF 30, 2019."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Yang, H.",
#       "quote": "- Yang, H., H. J. Kim, and L. Zhang."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "H. J. Kim",
#       "quote": "- Yang, H., H. J. Kim, and L. Zhang."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "L. Zhang",
#       "quote": "- Yang, H., H. J. Kim, and L. Zhang."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "Implementation of parallelism testing for four-parameter",
#       "quote": "Implementation of parallelism testing for four-parameter. PDA Journal of Pharmaceutical Science and Technology 66:262 -269."
#     },
#     {
#       "description": null,
#       "entity_type": "statistical_test",
#       "name": "parallelism testing",
#       "quote": "Implementation of parallelism testing for four-parameter."
#     },
#     {
#       "description": null,
#       "entity_type": "paper",
#       "name": "PDA Journal of Pharmaceutical Science and Technology",
#       "quote": "PDA Journal of Pharmaceutical Science and Technology 66:262 -269."
#     },
#     {
#       "description": null,
#       "entity_type": "author",
#       "name": "Yeh, S. T.",
#       "quote": "- Yeh, S. T."
#     },
#     {
#       "description": null,
#       "entity_type": "algorithm",
#       "name": "trapezoidal rule",
#       "quote": "Using trapezoidal rule for the area under a curve calculation."
#     }
#   ]
# }

# %%
all_entities = Entities(entities=[ent.model_dump() for entities in entities_from_chunks for ent in entities.entities])
len(all_entities)
# Out:
# 386

# %%
all_entities[39]
# Out:
# Entity(entity_type='statistical_test', name='equivalence approaches', description='A statistical test for comparing curves.', quote='We compare the curve similarity method (frequentist and Bayesian) to the traditional difference testing and equivalence approaches as well as to a recent frequentist test offered by Novick and Yang (2019).')

# %%
all_entities.deduplicate().to_jsonl(here() / "data" / "entities.jsonl")

# %%
all_entities = Entities.from_jsonl(here() / "data" / "entities.jsonl")
len(all_entities)
# Out:
# 280

# %%
len(all_entities), len(merged_entities), len(merged_post_fuzzy_entities)
# Out:
# (386, 292, 280)

# %%
merged_entities.to_jsonl(here() / "data" / "entities.jsonl")

# %%
from poorman_graphrag.entities import Relationships

relationship_extractor = lmb.StructuredBot(
    system_prompt=lmb.system(
        "You are an expert at identifying relationships between entities in scientific papers. "
        "You will be provided with a list of entities and their descriptions. "
        "You will also be provided with a list of relationship types. "
        "For each pair of entities, determine if and how they are related based on the provided relationship types. "
        "Return all relationships you can identify between the entities."
    ),
    model_name="gpt-4o",
    pydantic_model=Relationships,
    stream_target="none",
)

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm.auto import tqdm
import json

def extract_relationships_for_chunk(chunk):
    return relationship_extractor(
        lmb.user(
            "Here are the entities and their descriptions:",
            json.dumps(deduplicated_entities.model_dump_json()),
            "Here is a chunk of text to work with:",
            chunk.text
        )
    )

# Extract relationships in parallel
with ThreadPoolExecutor() as executor:
    batch_relationships = list(tqdm(
        executor.map(extract_relationships_for_chunk, chunks),
        total=len(chunks),
        desc="Extracting relationships"
    ))

# Combine all relationships
relationships = Relationships(
    relationships=[
        rel for batch in batch_relationships
        for rel in batch.relationships
    ]
)
# Out:
# Extracting relationships:   0%|          | 0/26 [00:00<?, ?it/s]

# %%
print(relationships)
# Out:
# relationships=[Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Paul Faya', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Adam P. Rauk', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Kristi L. Griffiths', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Bhavin Parekh', relation_type='related_to'), Relationship(source_name='Paul Faya', target_name='Eli Lilly and Company', relation_type='related_to'), Relationship(source_name='Adam P. Rauk', target_name='Eli Lilly and Company', relation_type='related_to'), Relationship(source_name='Kristi L. Griffiths', target_name='Eli Lilly and Company', relation_type='related_to'), Relationship(source_name='Bhavin Parekh', target_name='Eli Lilly and Company', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='curve similarity approach', relation_type='models'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='equivalence tests', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='frequentist approach', relation_type='contains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Bayesian approach', relation_type='contains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='potency', relation_type='explains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='reference standard', relation_type='explains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='test sample', relation_type='explains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='EC50', relation_type='explains'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='parallelism hypothesis', relation_type='models'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Paul Faya', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Adam P. Rauk', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Kristi L. Griffiths', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Bhavin Parekh', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Eli Lilly and Company', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='curve similarity approach', relation_type='models'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Four-Parameter Nonlinear Logistic Curve (4PL)', relation_type='models'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='Bayesian approach', relation_type='models'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='equivalence tests', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing in bioassay', target_name='F-test', relation_type='related_to'), Relationship(source_name='A curve similarity approach to parallelism testing i ...

# %%
len(all_entities)
# Out:
# 197

# %%
len(relationships.relationships)
# Out:
# 821

# %%
# Create networkx graph from entities and relationships
import networkx as nx
from typing import Dict

# Initialize directed graph
G = nx.DiGraph()

# Add all entities as nodes
entity_nodes: Dict[str, Entity] = {}
for entity in all_entities:
    # Use entity name as node identifier
    node_id = entity.name
    G.add_node(node_id, **entity.model_dump())
    entity_nodes[node_id] = entity

# Add relationships as edges
for rel in relationships.relationships:
    G.add_edge(
        rel.source_name,
        rel.target_name,
        relation_type=rel.relation_type,
    )

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")
# Out:
# Graph created with 224 nodes and 453 edges

# %%
import hvplot.networkx as hvnx

hvnx.draw(
    G,
    layout='kamada_kawai',
    # node_size=300,
    edge_line_width=1,
    arrows=True,
    width=800,
    height=600
)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='32dd09a0-8012-4c92-a8b3-13223c318ca5'>
#   <div id="fec78c9a-85ac-49dd-b138-9e08b4ba2d33" data-root-id="32dd09a0-8012-4c92-a8b3-13223c318ca5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"09d219a7-5326-427e-9380-e529dfacf43f":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"32dd09a0-8012-4c92-a8b3-13223c318ca5"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"706d44fc-fc97-4498-8e7d-0174a50e80ee","attributes":{"plot_id":"32dd09a0-8012-4c92-a8b3-13223c318ca5","comm_id":"a9de1d45d08247ba9ac3ea4d0b3bad65","client_comm_id":"bbaeadd93d7e4313ad1cff3c5aa6f179"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"09d219a7-5326-427e-9380-e529dfacf43f","roots":{"32dd09a0-8012-4c92-a8b3-13223c318ca5":"fec78c9a-85ac-49dd-b138-9e08b4ba2d33"},"root_ids":["32dd09a0-8012-4c92-a8b3-13223c318ca5"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import hvplot.networkx as hvnx
#       3 hvnx.draw(
# ----> 4     G,
#       5     layout='kamada_kawai',
#       6     # node_size=300,
#       7     edge_line_width=1,
#       8     arrows=True,
#       9     width=800,
#      10     height=600
#      11 )
#
# NameError: name 'G' is not defined
